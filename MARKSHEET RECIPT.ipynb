# %% [markdown]
# # CODE OF MARKSHEET

# %%
Maths_marks=int(input('enter maths marks'))
urdu_marks=int(input('enter urdu marks'))
English_marks=int(input('enter english marks'))
physics_marks=int(input('enter physcis marks'))
chemistry_marks=int(input('enter chemistry marks'))
Total_Marks=(Maths_marks+urdu_marks+English_marks+physics_marks+chemistry_marks)
percentage=(Total_Marks/500)*100


def grade():
    if percentage >=85 and percentage <=100:
        print("Grade : A-one")
    elif percentage>=80 and percentage <=90:
        print("Grade : A")
    elif percentage >=75 and percentage <=84:
        print("Grade : B")
    elif percentage >=70 and percentage <=74:
        print("Grade : C")
    elif percentage >=65 and percentage <70:
        print("Grade : D")
    elif percentage >=60 and percentage<65 :
        print("Grade : Fail")
    else:
        print("you need to improve yourselve")


print("\n\n\n\n\n\n\n\n\n\n\n\n")














serial=int(input('Serial Number: '))
print('\t\t\t\t\tMARKSHEET')
print("\n\n")
print('\t\t------------BOARD OF SECONDARY EDUCATION KARACHI------------')
print("\n\t")
ROLL_NUMBER=int(input('ROLL NUMBER : '))
print("\n\t")
name=input('NAME :')
print("\n\t")
print('SUBJECTS\t\t\t\tTOTAL MARKS\t\t\tOBTAINED MARKS')
print("\n\n")
print("Maths","\t\t\t\t\t\t100","\t\t\t\t",Maths_marks)
print("\n\t")
print("urdu","\t\t\t\t\t\t100","\t\t\t\t",urdu_marks)
print("\n\t")
print("English","\t\t\t\t\t100","\t\t\t\t",English_marks)
print("\n\t")
print("physcis","\t\t\t\t\t100"," \t\t\t\t",physics_marks)
print("\n\t")
print("chemistry","\t\t\t\t\t100","\t\t\t\t",chemistry_marks)
print("\n\n")
print("\t\t\t\t\t\t\t\tObtained marks :",Total_Marks)
print("\t\t\t\t\t\t\t\tPercentage :",percentage,"%")
grade()
print("\n\t")
print("Controller of Exams : -------------------")
# Out:
# enter maths marks90
# enter urdu marks89
# enter english marks77
# enter physcis marks98
# enter chemistry marks70
#
#
#
#
#
#
#
#
#
#
#
#
#
# Serial Number: 00123
# 					MARKSHEET
#
#
#
# 		------------BOARD OF SECONDARY EDUCATION KARACHI------------
#
#
# ROLL NUMBER : 19089
#
#
# NAME :ASAD ALI
#
#
# SUBJECTS				TOTAL MARKS			OBTAINED MARKS
#
#
#
# Maths 						100 				 90
#
#
# urdu 						100 				 89
#
#
# English 					100 				 77
#
#
# physcis 					100  				 98
#
#
# chemistry 					100 				 70
#
#
#
# 								Obtained marks : 424
# 								Percentage : 84.8 %
# Grade : A
#
#
# Controller of Exams : -------------------

# %% [markdown]
# # CODE OF RECIPT

# %%
print("         RECIPT".format())
print("**************************")
print("WELCOME TO THE SUPER MART".format())
print("*************************".format())
import time
a=time.strftime("%A,%b,%d/%Y/%I:%M %p",time.localtime())
print(a)
print("***********************************".format())
print("THANKS FOR COMING TO OUR SUPER MART".format())
print("\n\t")
sum=0
for i in range(1000):
    a=str(input("Item :"))
    print("--------------------")
    if a=="exit":
        break
    else:
        b=int(input("Price of item :"))
        print("--------------------")
        sum =sum+b
print("************************************")
print("Please pay",sum,'rupees to counter !')
o=int(input("Enter the amount of customer :"))
n=(o-sum)
print("Exchange Amount is !",n)
print("*************************************")
print("\n\n")
print("|||||||||||||||||||||||||||||||||||||||")
print("          Please come again !".format())
print("\n\n")
print("For any opnion call us toll free:0304737651")
# Out:
#          RECIPT
# **************************
# WELCOME TO THE SUPER MART
# *************************
# Monday,Feb,24/2020/05:23 PM
# ***********************************
# THANKS FOR COMING TO OUR SUPER MART
#
#
# Item :chocolate
# --------------------
# Price of item :600
# --------------------
# Item :lays
# --------------------
# Price of item :120
# --------------------
# Item :softdrink
# --------------------
# Price of item :120
# --------------------
# Item :juices
# --------------------
# Price of item :1300
# --------------------
# Item :soaps
# --------------------
# Price of item :300
# --------------------
# Item :detergents
# --------------------
# Price of item :99
# --------------------
# Item :exit
# --------------------
# ************************************
# Please pay 2539 rupees to counter !
# Enter the amount of customer :3000
# Exchange Amount is ! 461
# *************************************
#
#
#
# |||||||||||||||||||||||||||||||||||||||
#           Please come again !
#
#
#
# For any opnion call us toll free:0304737651
